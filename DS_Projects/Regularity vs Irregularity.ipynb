# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
n =random.sample(range(30), 10)
print(n)
# Out:
# [17, 13, 6, 7, 27, 21, 8, 10, 28, 3]

# %%
a = 10*n
a = np.array(a)
a
# Out:
# array([17, 13,  6,  7, 27, 21,  8, 10, 28,  3, 17, 13,  6,  7, 27, 21,  8,
#        10, 28,  3, 17, 13,  6,  7, 27, 21,  8, 10, 28,  3, 17, 13,  6,  7,
#        27, 21,  8, 10, 28,  3, 17, 13,  6,  7, 27, 21,  8, 10, 28,  3, 17,
#        13,  6,  7, 27, 21,  8, 10, 28,  3, 17, 13,  6,  7, 27, 21,  8, 10,
#        28,  3, 17, 13,  6,  7, 27, 21,  8, 10, 28,  3, 17, 13,  6,  7, 27,
#        21,  8, 10, 28,  3, 17, 13,  6,  7, 27, 21,  8, 10, 28,  3])

# %%
b = []
for i in range(0,100):
 n2 = random.randint(1,30)
 b.append(n2)
print(b)
# Out:
# [27, 21, 5, 17, 14, 9, 25, 29, 29, 23, 25, 3, 11, 26, 21, 5, 27, 11, 28, 20, 10, 13, 18, 2, 4, 5, 14, 11, 25, 21, 10, 4, 30, 7, 26, 22, 13, 5, 5, 21, 20, 21, 6, 19, 28, 15, 24, 1, 25, 27, 20, 26, 20, 26, 26, 19, 27, 26, 29, 22, 9, 21, 21, 25, 28, 3, 29, 27, 9, 28, 1, 16, 20, 15, 10, 30, 2, 27, 12, 3, 6, 1, 1, 15, 25, 22, 3, 29, 18, 12, 29, 4, 9, 14, 25, 28, 16, 4, 26, 9]

# %%
#ploting a histogram for a:
plt.style.use('ggplot')
plt.hist(a, bins=30) #Number of bins as the randomness range  
plt.xlabel('10 Randomly Generated Numbers from 1 to 30 Reapeted 10 Times')
plt.ylabel("Frequency of Each Number")
# Out:
# Text(0, 0.5, 'Frequency of Each Number')

# %%
#ploting a histogram for a:
plt.style.use('ggplot')
plt.hist(b, bins=30)
plt.xlabel('100 Randomly Generated Numbers from 1 to 30')
plt.ylabel("Frequency of Each Number")
# Out:
# Text(0, 0.5, 'Frequency of Each Number')
